# %%
from IPython.display import IFrame

# %% [markdown]
# # 第十三回: 微分の微分
#
# ## 13.2 等角射影

# %% [markdown]
# * (1502)"https://www.nationalgeographic.com/history/history-magazine/article/leonardo-da-vinci-transformed-mapping-art-science"
#   - https://goo.gl/maps/QYqK6svQTVnzrYph7

# %% [markdown]
# https://i.natgeofe.com/n/e8a127f0-943b-425e-bbbd-01073405e81d/imola-map.jpg?w=2048&h=1366![image.png](attachment:6c388dcc-8b4b-41b6-89cb-634c42b380dd.png)

# %% [markdown]
# * (1728 &ndash; 1777) [Johann Heinrich Lambert - Wikipedia](https://en.wikipedia.org/wiki/Johann_Heinrich_Lambert)
#   * (1772) [Lambert conformal conic projection - Wikipedia](https://en.wikipedia.org/wiki/Lambert_conformal_conic_projection)
# * (1777 &ndash; 1855) [Carl Friedrich Gauss - Wikipedia](https://en.wikipedia.org/wiki/Carl_Friedrich_Gauss)
# * (1826 &ndash; 1866) [Bernhard Riemann - Wikipedia](https://en.wikipedia.org/wiki/Bernhard_Riemann)
# * (1829 &ndash; 1900) [Elwin Bruno Christoffel - Wikipedia](https://en.wikipedia.org/wiki/Elwin_Bruno_Christoffel)
# * (1873 &ndash; 1941) [Tullio Levi-Civita - Wikipedia](https://en.wikipedia.org/wiki/Tullio_Levi-Civita)
# * (1879 &ndash; 1955) [Albert Einstein - Wikipedia](https://en.wikipedia.org/wiki/Albert_Einstein)

# %% [markdown]
# ::::{admonition} ask ai
# :class: tip
#
# * Gaussは地図作成の依頼を受けて曲率の研究を深めました
#
# :::{admonition} ask ai repeatedly
# :class: seealso
#
# * Lambertは、世界地図を円錐に投影する方法を発見しました。緯線と罫線は直交し、測地線を近似的に描くことができます
# * 等角投影法は測地線の研究に活用され、Levi-Civita接続やChristoffel係数の発明に繋がりました
# * Levi-Civita接続では、計量が保存され、ねじれはありません。
#   そのような性質を持つ直交座標系以外にも適用できることが発見されます
# * 残念ながら、現在の微分幾何学の教科書は、Christoffel記号やLevi-Civita接続の作図幾何学的な位置付けを失念しています
# :::
# ::::

# %% [markdown]
# ### 13.2.1 円錐投影法と測地線

# %% [markdown]
# * https://www.geogebra.org/m/ktve4sxz

# %%
IFrame("https://www.geogebra.org/materialxx/iframe/id/ktve4sxz/width/1904/height/1015", width=1000, height=500)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="https://www.geogebra.org/material/iframe/id/ktve4sxz/width/1904/height/1015"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
