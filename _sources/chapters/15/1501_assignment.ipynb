# %%
from IPython.display import IFrame

# %% [markdown]
# # 第十五回: 微分の微分 (3)
#
# ## 15.1 課題

# %% [markdown]
# ### 15.1.1 形式1

# %% [markdown]
# ::::{admonition} ask ai
# :class: tip
#
# * 三大発明とは?
#
# :::{admonition} ask ai repeatedly
# :class: seealso
#
# * 科学史における三大発明とは?
# * 私は、○○○の×××が科学革命を起こしたと考えます
# * それがなければ△△△のような影響があったかもしれません
# :::
# ::::

# %% [markdown]
# ### 15.1.2 形式2

# %% [markdown]
# ::::{admonition} ask ai
# :class: tip
#
# * 科学史において発展を阻害した要因はありましたか？
#
# :::{admonition} ask ai repeatedly
# :class: seealso
#
# * 私は、○○○の×××が科学の発展を阻害したと考えます
# * それがなければ△△△のような発展があったかもしれません
# :::
# ::::
