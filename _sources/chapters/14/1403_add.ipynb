# %%
from IPython.display import IFrame

# %% [markdown]
# # 第14回: 微分の微分 (2)
#
# ## 14.3 第一余弦定理とChristoffel記号の補足

# %% [markdown]
# \begin{eqnarray}
# b &=& c \cos(\alpha) + a \cos(\gamma) \\
# c &=& a \cos(\beta) + b \cos(\alpha)
#
# \end{eqnarray}

# %% [markdown]
# $$
# \begin{eqnarray}
# b &=& \left( a \cos(\beta) + b \cos(\alpha) \right) \cos(\alpha) + a \cos(\gamma) \\
#   &=& a \cos(\beta) \cos(\alpha)  + b^2 \cos^2(\alpha) + a \cos(\gamma) \\
#   &=& -a \cos(\beta) \cos(\theta)  + b^2 \cos^2(\theta) + a \cos(\gamma) \\
# b \left(1-\cos^2(\theta) \right) &=& a \cos(\gamma) - a \cos(\beta) \cos(\theta) \\
# b \sin^2(\theta) &=& \|proj_{\vec{u}}\ \vec{w}\| - \|proj_{\vec{v}}\ \vec{w}\| \cos(\theta) \\
# b &=& \frac{1}{sin^2(\theta)} \left( \|proj_{\vec{u}}\ \vec{w}\| - \|proj_{\vec{v}}\ \vec{w}\| \cos(\theta) \right)\\
#   &=& \frac{1}{sin^2(\theta)} \left( \frac{\vec{w}\cdot\vec{u}}{\vec{u}\cdot\vec{u}} - \frac{\vec{w}\cdot\vec{v}}{\vec{v}\cdot\vec{v}} \cos(\theta) \right) \\
#   &=& \Gamma^u
# \end{eqnarray}
# $$

# %% [markdown]
# $\alpha + \theta = \pi$ なので、$\cos(\alpha) = -\cos(\theta)$

# %% [markdown]
# $$
# \begin{eqnarray}
# c &=& -\frac{1}{sin^2(\theta)} \left( \|proj_{\vec{u}}\ \vec{w}\| \cos(\theta) - \|proj_{\vec{v}}\ \vec{w}\| \right)\\
#   &=& -\frac{1}{sin^2(\theta)} \left( \frac{\vec{w}\cdot\vec{u}}{\vec{u}\cdot\vec{u}} \cos(\theta) - \frac{\vec{w}\cdot\vec{v}}{\vec{v}\cdot\vec{v}} \right) \\
#   &=& \Gamma^v
# \end{eqnarray}
# $$

# %% [markdown]
# $$
# \vec{w} = \Gamma^{u}\ \vec{u} + \Gamma^{v}\ \vec{v}
# $$

# %% [markdown]
# ### 基底ベクトルが直交する場合

# %% [markdown]
# この後は直交系しか扱わない: $\theta=\frac{\pi}{2}$
#
# \begin{eqnarray}
# \cos{\theta} = 0 \\
# \sin{\theta} = 1
# \end{eqnarray}

# %% [markdown]
# $$
# \begin{eqnarray}
# b &=& \frac{1}{sin^2(\theta)} \left( \|proj_{\vec{u}}\ \vec{w}\| - \|proj_{\vec{v}}\ \vec{w}\| \cos(\theta) \right)\\
#   &=& \frac{\vec{w}\cdot\vec{u}}{\vec{u}\cdot\vec{u}} \\
#   &=& \Gamma^u
# \end{eqnarray}
# $$

# %% [markdown]
# $$
# \begin{eqnarray}
# c &=& -\frac{1}{sin^2(\theta)} \left( \|proj_{\vec{u}}\ \vec{w}\| \cos(\theta) - \|proj_{\vec{v}}\ \vec{w}\| \right)\\
#   &=& \frac{\vec{w}\cdot\vec{v}}{\vec{v}\cdot\vec{v}} \\
#   &=& \Gamma^v
# \end{eqnarray}
# $$

# %% [markdown]
# $$
# \begin{eqnarray}
# \vec{w} & =  \Gamma^{u}\ \vec{u} + \Gamma^{v}\ \vec{v} \\
#         & =  \|proj_{\vec{u}}\ \vec{w}\| \vec{u} + \|proj_{\vec{v}}\ \vec{w}\| \vec{v} \\
#         & =  \frac{\vec{w}\cdot\vec{u}}{\vec{u}\cdot\vec{u}}\ \vec{u} + \frac{\vec{w}\cdot\vec{v}}{\vec{v}\cdot\vec{v}}\ \vec{v}
# \end{eqnarray}
# $$

# %% [markdown]
# * https://www.geogebra.org/m/hcvvswzz

# %%
IFrame("https://www.geogebra.org/material/iframe/id/hcvvswzz/width/2544/height/1255", width=1000, height=500)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="https://www.geogebra.org/material/iframe/id/hcvvswzz/width/2544/height/1255"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
