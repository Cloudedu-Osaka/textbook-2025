# %%
from IPython.display import IFrame

# %% [markdown]
# # 第十四回: 微分の微分 (2)
#
# ## 14.2 複素指数関数と調和振動

# %% [markdown]
# ::::{admonition} ask ai
# :class: tip
#
# * Keplerの時代、大きな数の積は、三角関数表を逆引きし、
#   三角関数の加法定理を使って積を和をに変換しました。
#     * ちなみに、イスラム経由で伝わったインド数字を使っていますが、まだ小数点は発見されていません
#
# :::{admonition} ask ai repeatedly
# :class: seealso
#
# * より単純な積・和変換方法を模索したNapierは、$(1-10^{-7})^{10^7}$を底とする対数表を作成しました。
#   Napierはその関数をLogarithmと名付けました。
#     * ちなみにNapierは小数点を発見しました
# * Newtonは自身が発明した一般化された二項定理によって双曲線 $1/(1+x)$の積分を求め、
#   対数の和の法則を満たす対数関数であるらしいことを発見しました
# * Leibnizは自身が発明した微分のチェインルールを対数の和の法則に適用し、
#   極限による微分の定義に基づいて対数関数の微分を求めました
# * Eulerは、$(1+x/N)^N$の二項展開から指数関数の底を求めました。
#   底はNapierの対数の底の逆数になっていることを示しました
# * NewtonやLeibnizですらボンヤリとした認識しかできなかった対数と指数関数を、Eulerは一気に体系化しました。
#   Eulerは、$e$を底とする指数関数が微分で不変であること、
#   さらに、二階微分の符号が反転する微分方程式の解として複素指数関数を定義しました
# :::
# ::::

# %%
import math
n=5
1/((1-10**-n)**(10**n))
# Out:
# 2.7182954199804055

# %%
math.e
# Out:
# 2.718281828459045

# %% [markdown]
# * (1748) [Introductio in analysin infinitorum - Wikipedia](https://en.wikipedia.org/wiki/Introductio_in_analysin_infinitorum)

# %% [markdown]
# * https://www.geogebra.org/m/aezj93yg

# %%
IFrame("https://www.geogebra.org/material/iframe/id/aezj93yg/width/1905/height/1016", width=1000, height=500)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="https://www.geogebra.org/material/iframe/id/aezj93yg/width/1905/height/1016"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
